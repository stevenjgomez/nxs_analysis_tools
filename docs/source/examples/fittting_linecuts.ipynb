# %% [markdown]
# # Fitting linecuts using the lmfit package

# %% [markdown]
# ## Import functions

# %%
from nxs_analysis_tools.datareduction import load_data, Scissors
from nxs_analysis_tools.fitting import LinecutModel

from lmfit.models import GaussianModel, LinearModel

# %% [markdown]
# ## Load data

# %%
data = load_data('example_data/sample_name/15/example_hkli.nxs')
# Out:
# data:NXdata
#   @axes = ['H', 'K', 'L']
#   @signal = 'counts'
#   H = float64(100)
#   K = float64(150)
#   L = float64(200)
#   counts = float64(100x150x200)

# %% [markdown]
# ## Perform linecuts

# %%
s = Scissors(data=data)

# %%
linecut = s.cut_data(center=(0,0,0), window=(0.1,0.5,0.1))
# Out:
# Linecut axis: K
# Integrated axes: ['H', 'L']

# %% [markdown]
# ## The `LinecutModel` class

# %% [markdown]
# The workhorse of the fitting algorithm here is the `LinecutModel` class which wraps both the `Model` and `ModelResult` classes of the `lmfit` package, among other information.

# %%
lm = LinecutModel(data=linecut)

# %% [markdown]
# ## Create `lmfit` model

# %% [markdown]
# Use the `.set_model_components()` method to set the model to be used for fitting the linecut. The `model_components` parameter must be a `Model` or `list` of `Model` objects.

# %%
lm.set_model_components([GaussianModel(prefix='peak'), LinearModel(prefix='background')])

# %% [markdown]
# ## Set model constraints

# %% [markdown]
# Set constraints on the model using `.set_param_hint()`.

# %%
lm.set_param_hint('peakcenter', min=-0.1, max=0.1)

# %% [markdown]
# After the model and the hints have been specified, use the `.make_params()` method to initialize the parameters.

# %% [markdown]
# ## Initialize parameters

# %%
lm.make_params()
# Out:
# Parameters([('peakamplitude', <Parameter 'peakamplitude', value=1.0, bounds=[-inf:inf]>), ('peakcenter', <Parameter 'peakcenter', value=0.0, bounds=[-0.1:0.1]>), ('peaksigma', <Parameter 'peaksigma', value=1.0, bounds=[0:inf]>), ('backgroundslope', <Parameter 'backgroundslope', value=1.0, bounds=[-inf:inf]>), ('backgroundintercept', <Parameter 'backgroundintercept', value=0.0, bounds=[-inf:inf]>), ('peakfwhm', <Parameter 'peakfwhm', value=2.35482, bounds=[-inf:inf], expr='2.3548200*peaksigma'>), ('peakheight', <Parameter 'peakheight', value=0.3989423, bounds=[-inf:inf], expr='0.3989423*peakamplitude/max(1e-15, peaksigma)'>), ('peakcorrlength', <Parameter 'peakcorrlength', value=2.6682231793426188, bounds=[-inf:inf], expr='(2 * 3.141592653589793) / peakfwhm'>)])

# %% [markdown]
# ## Perform initial guess

# %% [markdown]
# Use the `.guess()` method to perform an initial guess.

# %%
lm.guess()

# %% [markdown]
# The initial values of the parameters that result can be viewed using the `.print_initial_params()` method.

# %%
lm.print_initial_params()
# Out:
# peaksigma
# 	min: 0
# peakfwhm
# 	expr: 2.3548200*peaksigma
# peakheight
# 	expr: 0.3989423*peakamplitude/max(1e-15, peaksigma)
# peakcenter
# 	min: -0.1
# 	max: 0.1

# %% [markdown]
# These can also be accessed through the individual `LinecutModel` objects.

# %%
lm.params
# Out:
# Parameters([('peakamplitude', <Parameter 'peakamplitude', value=219.88536567293792, bounds=[-inf:inf]>), ('peakcenter', <Parameter 'peakcenter', value=0.0, bounds=[-inf:inf]>), ('peaksigma', <Parameter 'peaksigma', value=0.06040268456375841, bounds=[0.0:inf]>), ('backgroundslope', <Parameter 'backgroundslope', value=2.3853065274578794e-14, bounds=[-inf:inf]>), ('backgroundintercept', <Parameter 'backgroundintercept', value=180.0195329458017, bounds=[-inf:inf]>), ('peakfwhm', <Parameter 'peakfwhm', value=0.14223744966442958, bounds=[-inf:inf], expr='2.3548200*peaksigma'>), ('peakheight', <Parameter 'peakheight', value=1452.279383796392, bounds=[-inf:inf], expr='0.3989423*peakamplitude/max(1e-15, peaksigma)'>), ('peakcorrlength', <Parameter 'peakcorrlength', value=44.17391708022779, bounds=[-inf:inf], expr='(2 * 3.141592653589793) / peakfwhm'>)])

# %% [markdown]
# ## Visualize the initial guesses

# %%
lm.plot_initial_guess()

# %% [markdown]
# ## Perform the fit

# %%
lm.fit()

# %% [markdown]
# ## Visualize the fit

# %%
lm.plot_fit()
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# The number of x values used to evaluate the fit curve can be set using the `numpoints` parameter, and any keyword arguments here will be passed to the `.plot()` method of the underlying `ModelResult` object.

# %%
lm.plot_fit(numpoints=1000)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ## Access the fit values

# %% [markdown]
# The x and y values of the fit are stored in the `.x` (identical to the raw x values) and the `.y_fit` attributes.

# %%
lm.x
# Out:
# array([-0.503356, -0.489933, -0.47651 , ...,  0.47651 ,  0.489933,
#         0.503356])

# %%
lm.y_fit
# Out:
# array([-1.505563e-09, -1.502143e-09, -1.481615e-09, ..., -1.481615e-09,
#        -1.502143e-09, -1.505563e-09])

# %% [markdown]
# The residuals are stored within the `ModelResult` class of the lmfit package, which is stored in the `.modelresult` attribute of the `LinecutModel` class.

# %%
lm.modelresult.residual
# Out:
# array([-1.507817e-09, -1.506447e-09, -1.506236e-09, ..., -1.506236e-09,
#        -1.506447e-09, -1.507817e-09])

# %% [markdown]
# ## Viewing the fit report

# %%
lm.print_fit_report()
# Out:
# [[Model]]
#     (Model(gaussian, prefix='peak') + Model(linear, prefix='background'))
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 76
#     # variables        = 5
#     chi-square         = 3.7857e-16
#     reduced chi-square = 5.3320e-18
#     Akaike info crit   = -3017.90553
#     Bayesian info crit = -3006.25186
#     R-squared          = 1.00000000
# ##  Warning: uncertainties could not be estimated:
#     backgroundslope:      at initial value
# [[Variables]]
#     peakamplitude:        183.644087 (init = 219.8854)
#     peakcenter:          -2.3217e-15 (init = 0)
#     peaksigma:            0.06000000 (init = 0.06040268)
#     backgroundslope:     -2.8067e-17 (init = 2.385307e-14)
#     backgroundintercept: -1.5062e-09 (init = 180.0195)
#     peakfwhm:             0.14128920 == '2.3548200*peaksigma'
#     peakheight:           1221.05658 == '0.3989423*peakamplitude/max(1e-15, peaksigma)'
#     peakcorrlength:       44.4703863 == '(2 * 3.141592653589793) / peakfwhm'
